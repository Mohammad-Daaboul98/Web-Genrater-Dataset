# %% [markdown]
# <h1>Dataset</h1>

# %%
import random
import os
import sys
data = [
"main-container{\n container{\n h-1 \n paragraph-lead \n btn-primary \n}\n}\n",
"main-container{\n text-center{\n h-1 \n paragraph-lead \n}\n container{\n card-deck{\n card{\n card-header{\n h-4 \n}\n card-body{\n card-title \n list-unstyled{\n li \n li \n li \n li \n}\n btn-outline-primary \n}\n}\n card{\n card-header{\n h-4 \n}\n card-body{\n card-title \n list-unstyled{\n li \n li \n li \n li \n}\n btn-outline-primary \n}\n}\n card{\n card-header{\n h-4 \n}\n card-body{\n card-title \n list-unstyled{\n li \n li \n li \n li \n}\n btn-outline-primary \n}\n}\n}\n}\n}\n",
"main-container{\n text-center{\n h-1 \n paragraph-lead \n}\n container{\n card-deck{\n card{\n card-header{\n h-4 \n}\n card-body{\n card-title \n list-unstyled{\n li \n li \n li \n li \n}\n btn-primary \n}\n}\n card{\n card-header{\n h-4 \n}\n card-body{\n card-title \n list-unstyled{\n li \n li \n li \n li \n}\n btn-primary \n}\n}\n card{\n card-header{\n h-4 \n}\n card-body{\n card-title \n list-unstyled{\n li \n li \n li \n li \n}\n btn-primary \n}\n}\n}\n}\n}\n",
"main{\n section-jumbotron-text-center{\n container{\n h-1 \n paragraph-lead \n btn-primary \n btn-secondary \n}\n}\n album-py-5-bg-light{\n container{\n row{\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-outline-secondary \n btn-outline-secondary \n}\n small-text-muted \n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-outline-secondary \n btn-outline-secondary \n}\n small-text-muted \n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-outline-secondary \n btn-outline-secondary \n}\n small-text-muted \n}\n}\n}\n}\n}\n}\n}\n}\n",
"main{\n album-py-5-bg-light{\n container{\n row{\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-outline-secondary \n btn-outline-secondary \n}\n small-text-muted \n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-outline-secondary \n btn-outline-secondary \n}\n small-text-muted \n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-outline-secondary \n btn-outline-secondary \n}\n small-text-muted \n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-outline-secondary \n btn-outline-secondary \n}\n small-text-muted \n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-outline-secondary \n btn-outline-secondary \n}\n small-text-muted \n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-outline-secondary \n btn-outline-secondary \n}\n small-text-muted \n}\n}\n}\n}\n}\n}\n}\n}\n",
"main{\n jumbotron{\n container{\n h-1 \n paragraph \n btn-primary \n}\n}\n container{\n text-center{\n row{\n col-md-4{\n h-2 \n paragraph \n btn-secondary \n }\n col-md-4{\n h-2 \n paragraph \n btn-secondary \n}\n col-md-4{\n h-2 \n paragraph \n btn-secondary \n}\n}\n hr \n}\n}\n}\n",
"main-container{\n text-center{\n container{\n row{\n col-md-4{\n h-2 \n paragraph \n btn-secondary \n}\n col-md-4{\n h-2 \n paragraph \n btn-secondary \n}\n col-md-4{\n h-2 \n paragraph \n btn-secondary \n}\n}\n hr \n}\n container{\n row{\n col-md-4{\n h-2 \n paragraph \n btn-secondary \n}\n col-md-4{\n h-2 \n paragraph \n btn-secondary \n}\n col-md-4{\n h-2 \n paragraph \n btn-secondary \n}\n}\n hr \n}\n container{\n row{\n col-md-4{\n h-2 \n paragraph \n btn-secondary \n}\n col-md-4{\n h-2 \n paragraph \n btn-secondary \n}\n col-md-4{\n h-2 \n paragraph \n btn-secondary \n}\n}\n hr \n}\n}\n}\n",
"main-container{\n container{\n text-center{\n h-1 \n paragraph-lead \n btn-dark \n}\n}\n br \n}\n",
"main-container{\n container{\n text-center{\n h-1 \n paragraph-lead \n btn-warning \n}\n}\n br \n}\n",
"main{\n section-jumbotron-text-center{\n container{\n h-1 \n paragraph-lead \n btn-warning \n}\n}\n container{\n row{\n col-md-4{\n text-center{\n h-2 \n paragraph \n btn-danger \n}\n}\n col-md-4{\n text-center{\n h-2 \n paragraph \n btn-danger \n}\n}\n col-md-4{\n text-center{\n h-2 \n paragraph \n btn-danger \n}\n}\n}\n}\n br \n album-py-5-bg-light{\n container{\n row{\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-primary \n btn-success \n}\n small-text-muted \n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-primary \n btn-success \n}\n small-text-muted \n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-primary \n btn-success \n}\n small-text-muted \n}\n}\n}\n}\n}\n}\n}\n}\n",
"main{\n carousel-slide \n album-py-5-bg-light{\n container{\n row{\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-danger \n btn-success \n}\n small-text-muted \n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-danger \n btn-success \n}\n small-text-muted \n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow-sm{\n svg-bd-placeholder-img-card-img-top \n card-body{\n p-card-text \n d-flex-center{\n btn-group{\n btn-danger \n btn-success \n}\n small-text-muted \n}\n}\n}\n}\n}\n}\n}\n container-marketing{\n row{\n col-lg-4{\n svg-140px \n h-2 \n paragraph \n p-btn{\n btn-outline-dark \n}\n}\n col-lg-4{\n svg-140px \n h-2 \n paragraph \n p-btn{\n btn-outline-dark \n}\n}\n col-lg-4{\n svg-140px \n h-2 \n paragraph \n p-btn{\n btn-outline-dark \n}\n}\n}\n}\n}\n",
"main-container{\n container-marketing{\n row{\n col-lg-4{\n svg-140px \n h-2 \n paragraph \n p-btn{\n btn-success \n}\n}\n col-lg-4{\n svg-140px \n h-2 \n paragraph \n p-btn{\n btn-success \n}\n}\n col-lg-4{\n svg-140px \n h-2 \n paragraph \n p-btn{\n btn-success \n}\n}\n}\n}\n hr \n container{\n card-deck{\n card{\n card-header{\n h-4 \n}\n card-body{\n card-title \n list-unstyled{\n li \n li \n li \n li \n}\n btn-danger \n}\n}\n card{\n card-header{\n h-4 \n}\n card-body{\n card-title \n list-unstyled{\n li \n li \n li \n li \n}\n btn-danger \n}\n}\n card{\n card-header{\n h-4 \n}\n card-body{\n card-title \n list-unstyled{\n li \n li \n li \n li \n}\n btn-danger \n}\n}\n}\n}\n}\n",
"main-container{\n container{\n card-deck{\n card{\n card-header{\n h-4 \n}\n card-body{\n svg-140px \n paragraph-lead \n btn-danger \n}\n}\n card{\n card-header{\n h-4 \n}\n card-body{\n svg-140px \n paragraph-lead \n btn-danger \n}\n}\n card{\n card-header{\n h-4 \n}\n card-body{\n svg-140px \n paragraph-lead \n btn-danger \n}\n}\n}\n}\n}\n",
"main-container{\n br \n text-center{\n row{\n col-md-4{\n svg-250px \n h-3 \n}\n col-md-4{\n svg-250px \n h-3 \n}\n col-md-4{\n svg-250px \n h-3 \n}\n}\n br \n row{\n col-md-4{\n svg-250px \n h-3 \n}\n col-md-4{\n svg-250px \n h-3 \n}\n col-md-4{\n svg-250px \n h-3 \n}\n}\n br \n row{\n col-md-4{\n svg-250px \n h-3 \n}\n col-md-4{\n svg-250px \n h-3 \n}\n col-md-4{\n svg-250px \n h-3 \n}\n}\n br \n}\n}\n",
"main{\n jumbotron-center{\n container{\n h-jumbotron \n paragraph-lead-text-muted \n p-btn{\n btn-primary-my-2 \n}\n}\n}\n}\n",
"main-container{\n br \n card-deck{\n col-md-4{\n svg-250px \n h-3 \n}\n card{\n card-header{\n h-4 \n}\n card-body{\n svg-140px \n paragraph-lead \n btn-danger \n}\n}\n}\n}\n",
"main-container{\n br \n card-deck{\n col-md-4{\n svg-250px \n h-3 \n}\n card{\n card-header{\n h-4 \n}\n card-body{\n svg-140px \n paragraph-lead \n btn-primary \n}\n}\n col-md-4{\n svg-250px \n h-3 \n}\n}\n}\n",
"main-container{\n card-deck{\n col-md-4{\n svg-250px \n h-3 \n}\n card{\n card-header{\n h-4 \n}\n card-body{\n svg-140px \n paragraph-lead \n btn-success \n}\n}\n col-md-4{\n svg-250px \n h-3 \n}\n}\n br \n card-deck{\n card{\n card-header{\n h-4 \n}\n card-body{\n svg-140px \n paragraph-lead \n btn-success \n}\n}\n col-md-4{\n svg-250px \n h-3 \n}\n card{\n card-header{\n h-4 \n}\n card-body{\n svg-140px \n paragraph-lead \n btn-success \n}\n}\n}\n}\n",
"main-container{\n container{\n card-deck{\n col-md-4{\n svg-250px \n h-3 \n}\n col-md-4{\n svg-500px \n h-3 \n}\n col-md-4{\n svg-250px \n h-3 \n}\n}\n}\n}\n",
"jumbotron-center{\n container{\n h-jumbotron \n paragraph-lead-text-muted \n p-btn{\n btn-primary-my-2 \n btn-secondary-my-2 \n}\n}\n}",
"album-py-5-bg-light{\n container{\n row{\n col-md-4{\n card-mb-4-shadow{\n card-img-top \n card-body{\n paragraph-card-text \n d-flex-justify-content-between{\n btn-group{\n btn-outline-secondary-sm \n btn-outline-secondary-sm \n}\n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow{\n card-img-top \n card-body{\n paragraph-card-text \n d-flex-justify-content-between{\n btn-group{\n btn-outline-secondary-sm \n btn-outline-secondary-sm \n}\n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow{\n card-img-top \n card-body{\n paragraph-card-text \n d-flex-justify-content-between{\n btn-group{\n btn-outline-secondary-sm \n btn-outline-secondary-sm \n}\n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow{\n card-img-top \n card-body{\n paragraph-card-text \n d-flex-justify-content-between{\n btn-group{\n btn-outline-secondary-sm \n btn-outline-secondary-sm \n}\n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow{\n card-img-top \n card-body{\n paragraph-card-text \n d-flex-justify-content-between{\n btn-group{\n btn-outline-secondary-sm \n btn-outline-secondary-sm \n}\n}\n}\n}\n}\n col-md-4{\n card-mb-4-shadow{\n card-img-top \n card-body{\n paragraph-card-text \n d-flex-justify-content-between{\n btn-group{\n btn-outline-secondary-sm \n btn-outline-secondary-sm \n}\n}\n}\n}\n}\n}\n}\n}\n",
"carousel-slide \n",
"container-marketing{\n row{\n col-lg-4{\n svg-140px \n h-2 \n paragraph \n p-btn{\n btn-secondary \n}\n}\n col-lg-4{\n svg-140px \n h-2 \n paragraph \n p-btn{\n btn-secondary \n}\n}\n col-lg-4{\n svg-140px \n h-2 \n paragraph \n p-btn{\n btn-secondary \n}\n\n}\n\n}\n}\n featurette-divider \n",
"container-marketing{\n row {\n col-md-7{\n h-featurette{\n text-muted \n}\n paragraph-lead \n}\n col-md-5{\n svg-500px \n}\n}\n}\n featurette-divider \n",
"section-jumbotron-text-center{\n container{\n h-1 \n paragraph-lead \n btn-warning \n}\n}\n",
"container{\n row{\n col-md-4{\n text-center{\n h-2 \n paragraph \n btn-danger \n}\n}\n col-md-4{\n text-center{\n h-2 \n paragraph \n btn-danger \n }\n }\n col-md-4{\n text-center{\n h-2 \n paragraph \n btn-danger \n}\n}\n}\n}\n",
"container{\n card-deck{\n card{\n card-header{\n h-4 \n}\n card-body{\n svg-140px \n paragraph-lead \n btn-danger \n}\n}\n card{\n card-header{\n h-4 \n}\n card-body{\n svg-140px \n paragraph-lead \n btn-danger \n}\n}\n card{\n card-header{\n h-4 \n}\n card-body{\n svg-140px \n paragraph-lead \n btn-danger \n}\n}\n}\n}\n"
]

header = [
"header{\n navbar-dark{\n container-fluid{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item{\n nav-link-active \n}\n nav-item{\n nav-link \n}\n nav-item{\n nav-link-disabled \n}\n}\n form-inline-success \n}\n}\n}\n}\n",
"header{\n navbar-danger{\n container-fluid{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item{\n nav-link-active \n}\n nav-item{\n nav-link \n}\n nav-item{\n nav-link-disabled \n}\n}\n form-inline-dark \n}\n}\n}\n}\n",
"header{\n navbar-danger{\n container-fluid{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item{\n nav-link-active \n}\n nav-item{\n nav-link \n}\n nav-item{\n nav-link-disabled \n}\n}\n form-inline-light \n}\n}\n}\n}\n",
"header{\n navbar-success{\n container-fluid{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item{\n nav-link-active \n}\n nav-item{\n nav-link \n}\n nav-item{\n nav-link-disabled \n}\n}\n form-dark \n}\n}\n}\n}\n",
"header{\n navbar-primary{\n container-fluid{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item{\n nav-link-active \n}\n nav-item{\n nav-link \n}\n nav-item{\n nav-link-disabled \n}\n}\n form-secondary \n}\n}\n}\n}\n",
"header{\n navbar-warning{\n container-fluid{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item{\n nav-link-active \n}\n nav-item{\n nav-link \n}\n nav-item{\n nav-link-disabled \n}\n}\n form-inline-dark \n}\n}\n}\n}\n",
"header{\n d-flex{\n h5-my-0 \n nav-my-2{\n a-text-dark \n a-text-dark \n a-text-dark \n a-text-dark \n}\n btn-outline-primary \n}\n}\n",
"header{\n d-flex{\n h5-my-0 \n nav-my-2{\n a-text-dark \n a-text-dark \n a-text-dark \n a-text-dark \n}\n btn-success \n}\n}\n",
"header{\n navbar-dark{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item-active{\n nav-link \n}\n nav-item{\n nav-link \n}\n nav-item{\n nav-link-disabled \n}\n nav-item-dropdown{\n nav-link-dropdown-toggle \n dropdown-menu{\n dropdown-item \n dropdown-item \n dropdown-item \n}\n}\n}\n form-inline-success \n}\n}\n}\n",
"header{\n navbar-primary{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item-active{\n nav-link \n}\n nav-item{\n nav-link \n}\n nav-item{\n nav-link-disabled \n}\n nav-item-dropdown{\n nav-link-dropdown-toggle \n dropdown-menu{\n dropdown-item \n dropdown-item \n dropdown-item \n}\n}\n}\n form-secondary \n}\n}\n}\n",
"header{\n container{\n navbar-collapse-primary{\n h-4 \n paragraph-lead \n}\n}\n}\n",
"header{\n container{\n navbar-collapse-success{\n h-4 \n paragraph-lead \n}\n}\n}\n",
"header{\n container{\n navbar-collapse-danger{\n h-4 \n paragraph-lead \n}\n}\n}\n",
"header{\n container{\n navbar-collapse-dark{\n h-4 \n paragraph-lead \n}\n}\n}\n",
"header{\n container{\n navbar-collapse-warning{\n h-4 \n paragraph-lead \n}\n}\n}\n",
"header{\n container{\n navbar-collapse-secondary{\n h-4 \n paragraph-lead \n}\n}\n}\n",
"header{\n container{\n navbar-collapse-light{\n h-4 \n paragraph-lead \n}\n}\n}\n",
"header{\n navbar-success{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item-active{\n nav-link-undisabled \n}\n nav-item-unactive{\n nav-link-undisabled \n}\n nav-item-unactive{\n nav-link-undisabled \n}\n}\n form-inline-light \n}\n}\n}\n",
"header{\n navbar-primary{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item-active{\n nav-link-undisabled \n}\n nav-item-unactive{\n nav-link-undisabled \n}\n nav-item-unactive{\n nav-link-disabled \n}\n}\n form-inline-light \n}\n}\n}\n",
"header{\n navbar-dark{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item-active{\n nav-link-undisabled \n}\n nav-item-unactive{\n nav-link-undisabled \n}\n nav-item-unactive{\n nav-link-disabled \n}\n}\n form-inline-light \n}\n}\n}\n",
"header{\n navbar-light{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item-active{\n nav-link-undisabled \n}\n nav-item-unactive{\n nav-link-undisabled \n}\n nav-item-unactive{\n nav-link-disabled \n}\n}\n form-inline-light \n}\n}\n}\n",
"header{\n navbar-warning{\n navbar-brand \n navbar-toggler{\n navbar-toggler-icon \n}\n navbar-collapse{\n navbar-nav{\n nav-item-active{\n nav-link-undisabled \n}\n nav-item-unactive{\n nav-link-undisabled \n}\n nav-item-unactive{\n nav-link-disabled \n}\n}\n form-inline-light \n}\n}\n}\n",
"header{\n collapse-bg-primary{\n container{\n row{\n col-sm-8-col-md-7-py-4{\n h-4-text-white \n paragraph-lead-light \n}\n col-sm-4-offset-md-1-py-4{\n h-4-text-white \n list-unstyled-only{\n li{\n a-text-white \n}\n li{\n a-text-white \n}\n li{\n a-text-white \n}\n}\n}\n}\n}\n}\n navbar-dark-bg-primary-shadow{\n d-flex-justify-content-between{\n a-navbar-brand-d-flex-align-items-center \n navbar-toggler-icon-span \n}\n}\n}\n",
"header{\n collapse-bg-dark{\n container{\n row{\n col-sm-8-col-md-7-py-4{\n h-4-text-white \n paragraph-lead-text-muted \n}\n col-sm-4-offset-md-1-py-4{\n h-4-text-white \n list-unstyled-only{\n li{\n a-text-white \n}\n li{\n a-text-white \n}\n li{\n a-text-white \n}\n}\n}\n}\n}\n}\n navbar-dark-bg-dark-shadow{\n d-flex-justify-content-between{\n a-navbar-brand-d-flex-align-items-center \n navbar-toggler-icon-span \n}\n}\n}\n",
"header{\n collapse-bg-success{\n container{\n row{\n col-sm-8-col-md-7-py-4{\n h-4-text-white \n paragraph-lead-light \n}\n col-sm-4-offset-md-1-py-4{\n h-4-text-white \n list-unstyled-only{\n li{\n a-text-white \n}\n li{\n a-text-white \n}\n li{\n a-text-white \n}\n}\n}\n}\n}\n}\n navbar-dark-bg-success-shadow{\n d-flex-justify-content-between{\n a-navbar-brand-d-flex-align-items-center \n navbar-toggler-icon-span \n}\n}\n}\n",
"header{\n collapse-bg-danger{\n container{\n row{\n col-sm-8-col-md-7-py-4{\n h-4-text-white \n paragraph-lead-light \n}\n col-sm-4-offset-md-1-py-4{\n h-4-text-white \n list-unstyled-only{\n li{\n a-text-white \n}\n li{\n a-text-white \n}\n li{\n a-text-white \n}\n}\n}\n}\n}\n}\n navbar-dark-bg-danger-shadow{\n d-flex-justify-content-between{\n a-navbar-brand-d-flex-align-items-center \n navbar-toggler-icon-span \n}\n}\n}\n",
"header{\n collapse-bg-info{\n container{\n row{\n col-sm-8-col-md-7-py-4{\n h-4-text-white \n paragraph-lead-light \n}\n col-sm-4-offset-md-1-py-4{\n h-4-text-white \n list-unstyled-only{\n li{\n a-text-white \n}\n li{\n a-text-white \n}\n li{\n a-text-white \n}\n}\n}\n}\n}\n}\n navbar-dark-bg-info-shadow{\n d-flex-justify-content-between{\n a-navbar-brand-d-flex-align-items-center \n navbar-toggler-icon-span \n}\n}\n}\n"
]

# %% [markdown]
# <h1>Header Section</h1>

# %%
for i in range(0,9000):
  out ='/content/txt/{}.txt'.format(i)
  res  = random.sample((header), 1)
  with open(out, "w") as f:
    for j in res:
      print(j, file=f)

# %% [markdown]
# <h1>Main Section</h1>

# %%
#Dont run this code multiple time
selected = []
for i in range(0, 9000):
  out ='/content/txt/{}.txt'.format(i)
  rand_0 = random.randint(1, 4)
  res_0  = random.sample((data), rand_0)
  # rand_1 = random.randint(1, 5)
  # res_1  = random.sample((data), rand_1)
  # selected.append(res_0 + res_1)
  selected.append(res_0)
  # for (el1 , el2) in zip(res_0, res_1):
  for el1 in res_0:
    # if el1 not in selected[0] and el2 not in selected[0]:
    if el1 not in selected[0]: 
      with open(out, 'a+') as f:
        for j in res_0:
          print(j, file=f)
      # with open(out, "a+") as fd:
      #   for j in res_1:
      #     print(j, file=fd)
    elif os.path.exists(out):
      os.remove(out)

# %%
count = 0
for root_dir, cur_dir, files in os.walk(r'/content/txt'):
    count += len(files)
print('file count:', count)

# %%
directory = os.fsencode('/content/txt')
    
for file , newFile in zip(os.listdir(directory), range(count)):
  out ='/content/gui/{}.gui'.format(newFile)
  filename = os.fsdecode(file)
  with open('/content/txt/'+filename, 'r') as r, open(out, 'w') as o:
    for line in r:
      if line.strip():
        o.write(line)

# %% [markdown]
# Add empty str and before ( { )

# %%
directory = os.fsencode('/content/gui')
    
for file in os.listdir(directory):
  filename = os.fsdecode(file)
  with open('/content/gui/'+filename, 'r') as inp:
    fixed = inp.read().replace('{', ' {')
  with open('/content/gui/'+filename, 'w') as out:
    out.write(fixed)

# %% [markdown]
# Add empty str after ( , )

# %%
# for file in os.listdir(directory):
#   filename = os.fsdecode(file)
#   with open('/content/gui/'+filename, 'r') as inp:
#     fixed1 = inp.read().replace(',', ', ')
#   with open('/content/gui/'+filename, 'w') as out:
#     out.write(fixed1)

# %%
# !zip -r "gui.zip" "gui"
